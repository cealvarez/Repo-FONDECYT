# %%
import pandas as pd
from numpy import sqrt
import csv

# %%
datos = pd.read_csv("transition_log_V4.csv", sep=';')
datos
# Out:
#       id_paciente  id_paciente.1      transicion    fecha_inicio  \
# 0           58286          58286       Delegador  28-08-14 11:19
# 1           89555          89555          Casual  22-05-15 17:00
# 2            9176           9176       Delegador   28-01-13 8:42
# 3           92070          92070  Deleg. reasig.  27-11-12 16:48
# 4           89887          89887  Deleg. reasig.  06-07-12 18:28
# 5             630            630          Casual   30-07-15 9:04
# 6          112448         112448          Interr  07-05-13 14:09
# 7          108167         108167          Casual  06-08-14 11:19
# 8          115276         115276  Deleg. reasig.  25-11-13 11:21
# 9           16698          16698  Deleg. reasig.  06-12-14 12:28
# 10          76740          76740          Casual  29-10-12 16:41
# 11          31010          31010       Delegador   30-06-12 9:22
# 12          94744          94744  Deleg. reasig.  30-04-12 12:36
# ...
